# %% [markdown]
# 6.1

# %%
# Draw 2 points at (1, 3) and (8,10)
import matplotlib.pyplot as plt
import numpy as np

xpoints = ([1, 8])
ypoints = ([3,10]) 


plt.plot(xpoints, ypoints, 's')
plt.show()

# %%
# Draw a line from point (1, 3) to point (8,10)
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10]) 


plt.bar(xpoints, ypoints, color = "green")
plt.show()

# %%
# Draw a line to join points (1, 3), (2, 8), (6, 1) and (8,10)
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10]) 

plt.plot(xpoints, ypoints, color="hotpink")
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.colors import Normalize
from numpy.random import rand
 
data = [2, 3, 5, 6, 8, 12, 7, 5]
fig, ax = plt.subplots(1, 1)
 
# Get a color map
my_cmap = cm.get_cmap('jet')
 
# Get normalize function (takes data in range [vmin, vmax] -> [0, 1])
my_norm = Normalize(vmin=0, vmax=8)
 
ax.bar(range(8), rand(8), color=my_cmap(my_norm(data)))
plt.show()
# Out:
# C:\Users\Savvy Coders\AppData\Local\Temp\ipykernel_13192\1666864016.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   my_cmap = cm.get_cmap('jet')

# %% [markdown]
# Group Activity

# %%
# Group 4 Test CSV File


import pandas as pd
import matplotlib.pyplot as plt
import numpy as pd


df = pd.read_csv('..\C:\Users\Savvy Coders\savvycoders\Capstone\Renter_Households_by_Income_Category.csv)
df
# Out:
#   Cell In[44], line 9
#     df = pd.read_csv('..\C:\Users\Savvy Coders\savvycoders\Capstone\Renter_Households_by_Income_Category.csv)
#                      ^
# SyntaxError: unterminated string literal (detected at line 9)

# %% [markdown]
# Tuesday:

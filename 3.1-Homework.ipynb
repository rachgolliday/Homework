# %%
1. Algorithms is a way to keep data in order for it to make sense at the end of a project
2. Programs have to be ran before manually before they are able to run by computers alone
3. Formal Language
4. _ , A-Z
5. Error in the coding process, not allowing data to produce what the instructor is asking it to
6. Reguarly test your code lines
7. break, as, none, del, and

Real Python Tutorials
https://realpython.com/
# Below are details about me

'''
My name is Rachael.
My favorite food is chocolate.
My favorite job is one where I can be expressive.
'''


a = 1
b = 2 
c = 3
d = 4
e = str('The color pink is pretty!')

print(a, b, c, d, e)

print(d)

savvy = str('Learning Data Analytics and Python is Awesome!')

# Slicing before "ing" and ending before "and"

savvy = "Learning Data Analytics and Python is Awesome!"
print(savvy[5:24])

# Replace text in string
savvy 
print('savvy.replace("Awesome!")')

g = savvy.replace("Awesome!", "Great!")
print(g)

# This strong contains age, name and height

name = 'Rachael'
age = '27'
height = '5.5'

'''
Hi my name is {name},
I am {height}, 
and {age} old today.
'''
